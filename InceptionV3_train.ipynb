# %%
cd /content/drive/MyDrive/NCKH/Code/Caption-InceptionV3+Roberta-LSTM
# Out:
# /content/drive/.shortcut-targets-by-id/1NkTHnaM_oDG4NaiVA3CKQXCDq1JIC16Q/NCKH/Code/Caption-InceptionV3+Roberta-LSTM

# %%
ls
# Out:
# config.py             model_data/   requirements.txt  test.py
# InceptionV3_.ipynb    __pycache__/  run.py            train_val_data/
# InceptionV3_train.py  README.md     test_data/        utils/

# %%
# !git config --global user.name "votrieuvy1661"

# %%
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
